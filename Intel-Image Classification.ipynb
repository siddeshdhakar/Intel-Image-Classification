# %%
import pandas as pd
import os
import numpy as np
import cv2
import tensorflow as tf
from sklearn.metrics import confusion_matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.utils import shuffle

# %%
classes = ['mountain','street','glacier','buildings','sea','forest']

# %%
class_label = {'mountain':0,'street':1,'glacier':2,'buildings':3,'sea':4,'forest':5}
num_lb = 6

# %%
def load_data():
    datasets = ['seg_train/seg_train','seg_test/seg_test']
    size = (150,150)
    output = []
    for dataset in datasets:
        directory =  os.path.join('C:' + dataset)
        images = []
        labels = []
        for folder in os.listdir(directory):
            curr_label = class_label[folder]
            for file in os.listdir(directory + '/' + folder):
                img_path = directory + '/' + folder + '/' + file
                curr_img = cv2.imread(img_path)
                curr_img = cv2.resize(curr_img,size)
                images.append(curr_img)
                labels.append(curr_label)
        images,labels = shuffle(images,labels)
        images = np.array(images,dtype = 'float32')
        labels = np.array(labels,dtype = 'int32')
        output.append((images,labels))
        
    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()

# %%
print ("Number of training examples: " + str(train_labels.shape[0]))
print ("Number of testing examples: " + str(test_labels.shape[0]))
print ("Each image is of size: " + str(train_images.shape[1:]))
# Out:
# Number of training examples: 14034
# Number of testing examples: 3000
# Each image is of size: (150, 150, 3)

# %%
import matplotlib.pyplot as plt

# %%
np.bincount(train_labels)

plt.pie(np.bincount(train_labels),labels = classes,autopct='%1.1f%%')

plt.title('Distribution')

plt.show()

# %%
plt.imshow(train_images[3]/255.0)

# %%
# train_labels[3]

# %%
train_images.shape,test_images.shape
# Out:
# ((14034, 150, 150, 3), (3000, 150, 150, 3))

# %%
train_images = train_images/255.0
test_images = test_images/255.0

# %%
model = tf.keras.Sequential([
    
                             tf.keras.layers.Conv2D(32,(3,3),activation = 'relu', input_shape = (150, 150, 3)),
                             tf.keras.layers.MaxPooling2D(2,2),
                             tf.keras.layers.Conv2D(64,kernel_size = (3,3),activation = 'relu'),
                             tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
                             tf.keras.layers.Conv2D(128,kernel_size = (3,3),activation = 'relu'),
                             tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
                             tf.keras.layers.Flatten(),
                             tf.keras.layers.Dense(256, activation = 'relu'),
                             tf.keras.layers.Dense(512, activation = 'relu'),
                             tf.keras.layers.Dense(6,activation = 'softmax')
                                  ])

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, batch_size=128, epochs=20, validation_split = 0.2)
# Out:
# Train on 11227 samples, validate on 2807 samples
# Epoch 1/20
# 11227/11227 [==============================] - 444s 40ms/sample - loss: 213.2281 - acc: 0.4482 - val_loss: 4.9105 - val_acc: 0.5796
# Epoch 2/20
# 11227/11227 [==============================] - 260s 23ms/sample - loss: 2.3598 - acc: 0.6701 - val_loss: 4.0438 - val_acc: 0.4806
# Epoch 3/20
# 11227/11227 [==============================] - 211s 19ms/sample - loss: 0.7729 - acc: 0.8081 - val_loss: 2.4731 - val_acc: 0.6309
# Epoch 4/20
# 11227/11227 [==============================] - 203s 18ms/sample - loss: 0.4399 - acc: 0.8714 - val_loss: 2.3763 - val_acc: 0.6562
# Epoch 5/20
# 11227/11227 [==============================] - 168s 15ms/sample - loss: 0.2082 - acc: 0.9346 - val_loss: 3.1533 - val_acc: 0.5725
# Epoch 6/20
# 11227/11227 [==============================] - 166s 15ms/sample - loss: 0.1822 - acc: 0.9429 - val_loss: 2.5550 - val_acc: 0.6544
# Epoch 7/20
# 11227/11227 [==============================] - 174s 16ms/sample - loss: 0.1048 - acc: 0.9693 - val_loss: 2.5313 - val_acc: 0.6758
# Epoch 8/20
# 11227/11227 [==============================] - 163s 14ms/sample - loss: 0.0729 - acc: 0.9815 - val_loss: 2.5203 - val_acc: 0.6758
# Epoch 9/20
# 11227/11227 [==============================] - 166s 15ms/sample - loss: 0.0613 - acc: 0.9850 - val_loss: 2.6574 - val_acc: 0.6733
# Epoch 10/20
# 11227/11227 [==============================] - 174s 16ms/sample - loss: 0.0584 - acc: 0.9872 - val_loss: 2.6944 - val_acc: 0.6933
# Epoch 11/20
# 11227/11227 [==============================] - 166s 15ms/sample - loss: 0.0624 - acc: 0.9879 - val_loss: 2.5200 - val_acc: 0.6683
# Epoch 12/20
# 11227/11227 [==============================] - 192s 17ms/sample - loss: 0.0602 - acc: 0.9869 - val_loss: 2.5731 - val_acc: 0.6737
# Epoch 13/20
# 11227/11227 [==============================] - 171s 15ms/sample - loss: 0.0588 - acc: 0.9890 - val_loss: 2.7232 - val_acc: 0.6715
# Epoch 14/20
# 11227/11227 [==============================] - 212s 19ms/sample - loss: 0.0566 - acc: 0.9909 - val_loss: 2.7122 - val_acc: 0.6797
# Epoch 15/20
# 11227/11227 [==============================] - 168s 15ms/sample - loss: 0.0387 - acc: 0.9950 - val_loss: 2.6408 - val_acc: 0.6851
# Epoch 16/20
# 11227/11227 [==============================] - 180s 16ms/sample - loss: 0.0634 - acc: 0.9880 - val_loss: 2.7748 - val_acc: 0.6854
# Epoch 17/20
# 11227/11227 [==============================] - 164s 15ms/sample - loss: 0.0697 - acc: 0.9866 - val_loss: 3.4174 - val_acc: 0.6281
# Epoch 18/20
# 11227/11227 [==============================] - 166s 15ms/sample - loss: 0.1206 - acc: 0.9758 - val_loss: 3.1377 - val_acc: 0.6669
# Epoch 19/20
# 11227/11227 [==============================] - 162s 14ms/sample - loss: 0.0873 - acc: 0.9813 - val_loss: 3.6846 - val_acc: 0.6309
# Epoch 20/20
# 11227/11227 [==============================] - 161s 14ms/sample - loss: 0.1345 - acc: 0.9693 - val_loss: 3.8213 - val_acc: 0.6181

# %%
test_loss = model.evaluate(test_images, test_labels)
# Out:
# 3000/3000 [==============================] - 40s 13ms/sample - loss: 3.9124 - acc: 0.6137

# %%
predictions = model.predict(test_images)     
pred_labels = np.argmax(predictions, axis = 1)

# %%
BOO = test_labels == pred_labels

# %%
mislabeled_indices = np.where(BOO == 0)
mislabeled_images = test_images[mislabeled_indices]
mislabeled_labels = pred_labels[mislabeled_indices]

# %%
mislabeled_images.shape
# Out:
# (1159, 150, 150, 3)

# %%
plt.imshow(mislabeled_images[2]/255.)
plt.title(mislabeled_labels[2])
# Out:
# Text(0.5, 1.0, '3')

# %%
mislabeled_labels[1]
# Out:
# 5

# %%
CM = confusion_matrix(test_labels, pred_labels)
ax = plt.axes()
sns.heatmap(CM, annot=True, 
           annot_kws={"size": 10}, 
           xticklabels=classes, 
           yticklabels=classes, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from keras.applications.vgg16 import decode_predictions
